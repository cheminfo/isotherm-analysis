# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../testFiles/CO2_25C_lewatit.csv', skiprows=41)

# %%
df.head()
# Out:
#    Time [minutes]  Mass [mg]  Delta Mass [%]  dm/dt [%/minute]  \
# 0            0.00    43.4779      100.000000          1.809178
# 1            0.08    43.4082       99.839689          1.294706
# 2            0.17    43.3317       99.663737          1.180673
# 3            0.25    43.2626       99.504806          1.092400
# 4            0.33    43.1858       99.328164          0.985663
#
#    Target Incubator Temperature [�C]  Actual Incubator Temperature [�C]  \
# 0                                 25                               24.7
# 1                                 25                               24.6
# 2                                 25                               24.6
# 3                                 25                               24.6
# 4                                 25                               24.6
#
#    Target Preheater Temperature [�C]  Actual Preheater Temperature [�C]  \
# 0                                100                               24.1
# ...

# %%
plt.plot(df['Target Relative Pressure [%]'])
